# %% [markdown]
# # Today's at the moment stock data analysis

# %% [markdown]
# This notebook looks at today's at the moment stock data, to find the top five largest stocks by
# 3 month average volume for a particular time. Use yfinance to get information about each of those stocks, and
# use data visualization to see how each of those stocks is performing for the past year. The goal
# is to check to see when the stock had it's highest and lowest price. Looking at one of those five
# stocks for a period of one year, this notebook shows the closing and opening price from the last
# time the data was scrapped, and goes back daily for one year.
#
# **Dates and times are subject to the stock trading calendar.**

# %% [markdown]
# Using  yfinance, which is built in on yahoo finance API for analysis, and for visualization plotly is used to create interactive graphs of the data.

# %%
import yfinance as yf
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import plotly.express as px


# to print current time and a day of the week and formatted
date = pd.Timestamp(datetime.datetime.today())
today = f"{date.day_name()} {date.strftime('%m-%d-%y %H:%M:%S')} "
today
#print(f"Today is {today.day_name()} {today.strftime('%m-%d-%y %H:%M:%S')} ")
# Out:
# 'Tuesday 03-28-23 22:43:16 '

# %% [markdown]
# A function is created to change 'M', 'B', 'T' to its corresponding 10^n and changing the data type

# %%
def convert_scale(x):
    if type(x) == float or type(x) == int:
        return x
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000.0
    elif 'B' in x:
        if len(x) > 1:
            return float(x.replace('B', '')) * 1000000000
        return 1000000.0
    elif 'T' in x:
        return float(x.replace('T', '')) * 1000000000000
    else:
        return float(x)

# %% [markdown]
# ## Feature 1: Loading Data
# As per the requirement, two datasets are to be loaded in. Pandas .read_html function is used to read in HTML tables into a list of Dataframe objects. Tables are read in from https://finance.yahoo.com/. From there, most-active, gainers and losers tables are webscrapped.
#
# The default filters used on the links.
# 1. most-active
#     Region: United States, Market Cap (Intraday): Mid Cap and Large Cap and Mega Cap, Volume:greater than 5000000
# 2. gainers
#     % Change in Price (Intraday):greater than 3, Region: United States, Market Cap (Intraday): Mid Cap and Large Cap and Mega Cap, Volume:greater than 15000
# 3. losers
#     % Change in Price (Intraday):less than -2.5, Region: United States, Market Cap (Intraday): Mid Cap and Large Cap and Mega Cap, Volume:greater than 20000

# %% [markdown]
# Pandas module was imported.
# Using the read_html() method and passing the URL, results in get all the HTML tables from the website. The read_html() method returns a list.
# Now that there is a list holding the tables, in order to access the first element in the list, pass the data as an argument to the Pandas Dataframe() method to create new dataset.

# %%
# reading in from a website and getting only the 1st page
most_active = pd.read_html('https://finance.yahoo.com/most-active')[0]
print(most_active.shape) #shows the shape of table
most_active.head() #print first 5 rows
# Out:
# (25, 10)
#   Symbol                              Name  Price (Intraday)  Change % Change  \
# 0   BABA     Alibaba Group Holding Limited             98.40   12.28  +14.26%
# 1   TSLA                       Tesla, Inc.            189.19   -2.62   -1.37%
# 2    AMC  AMC Entertainment Holdings, Inc.              5.15    0.60  +13.19%
# 3    CCL        Carnival Corporation & plc              9.33    0.54   +6.14%
# 4   ABEV                        Ambev S.A.              2.78    0.12   +4.51%
#
#      Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  118.057M           22.989M   256.858B           54.07            NaN
# 1   98.275M          176.437M   598.616B           52.41            NaN
# 2   87.142M           35.848M     2.644B             NaN            NaN
# 3     72.3M           40.575M    12.125B             NaN            NaN
# 4   62.223M           25.781M    43.762B           15.44            NaN

# %%
# reading in 2nd table
gainers = pd.read_html('https://finance.yahoo.com/gainers')[0]
print(gainers.shape)
gainers.head()
# Out:
# (25, 10)
#   Symbol                              Name  Price (Intraday)  Change % Change  \
# 0  LINRF        Liontown Resources Limited             1.670   0.645  +62.93%
# 1  PHJMF  PT Hanjaya Mandala Sampoerna Tbk             0.077   0.020  +35.09%
# 2    IHS               IHS Holding Limited             8.540   1.440  +20.28%
# 3    PVH                         PVH Corp.            88.360  14.740  +20.02%
# 4   ITCI    Intra-Cellular Therapies, Inc.            55.730   7.850  +16.40%
#
#    Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  108330              8302     3.671B             NaN            NaN
# 1  209275            316318    12.229B             NaN            NaN
# 2  872623            163945     2.833B             NaN            NaN
# 3  4.694M            1.033M     5.599B           13.81            NaN
# 4  3.622M            748316      5.31B             NaN            NaN

# %%
# reading in 3rd table
losers = pd.read_html('https://finance.yahoo.com/losers')[0]
print(losers.shape)
losers.head()
# Out:
# (25, 10)
#    Symbol                                   Name  Price (Intraday)  Change  \
# 0  FRC-PI                    First Republic Bank              6.10   -0.84
# 1  FRC-PH                    First Republic Bank              5.86   -0.77
# 2   TYCMY  Tingyi (Cayman Islands) Holding Corp.             32.34   -3.81
# 3     DRS                     Leonardo DRS, Inc.             11.60   -1.25
# 4     SYM                          Symbotic Inc.             20.94   -2.03
#
#   % Change  Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  -12.10%  501408            175180     3.846B            0.77            NaN
# 1  -11.61%  354664            128058     3.775B            0.74            NaN
# 2  -10.54%  132378              6761      9.11B           20.86            NaN
# 3   -9.73%  2.086M            658455     3.018B            4.20            NaN
# 4   -8.84%  433807            460405    11.633B             NaN            NaN

# %% [markdown]
# ## Feature 2: Clean and operate on the data while combining them.

# %% [markdown]
# The concat() function was used to combine multiple datasets to create a new one. Concat
# function stacks the dataset on top of each other. Then analysis can be performed on the new
# combined dataset. To have a continuous index the 'ignore_index=True' parameter was used. A
# custom function that converts 'M', 'B', and 'T' into corresponding 10^n values was used. The
# fillna() function was used to replace Nan values with 0. The drop() function was used to delete a
# column.

# %%
# joining 3 datasets into 1 dataframe.
stocks_df = pd.concat([most_active, gainers, losers],  ignore_index=True)
print(stocks_df.shape) # shows shape of new dataframe
print(f'Datatype before the change \n ')
stocks_df.info() 
stocks_df.head() # prints top 5 rows
# Out:
# (75, 10)
# Datatype before the change
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symbol             75 non-null     object
#  1   Name               75 non-null     object
#  2   Price (Intraday)   75 non-null     float64
#  3   Change             75 non-null     float64
#  4   % Change           75 non-null     object
#  5   Volume             75 non-null     object
#  6   Avg Vol (3 month)  75 non-null     object
#  7   Market Cap         75 non-null     object
#  8   PE Ratio (TTM)     35 non-null     float64
#  9   52 Week Range      0 non-null      float64
# dtypes: float64(4), object(6)
# memory usage: 6.0+ KB
#   Symbol                              Name  Price (Intraday)  Change % Change  \
# 0   BABA     Alibaba Group Holding Limited             98.40   12.28  +14.26%
# 1   TSLA                       Tesla, Inc.            189.19   -2.62   -1.37%
# 2    AMC  AMC Entertainment Holdings, Inc.              5.15    0.60  +13.19%
# 3    CCL        Carnival Corporation & plc              9.33    0.54   +6.14%
# 4   ABEV                        Ambev S.A.              2.78    0.12   +4.51%
#
#      Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  118.057M           22.989M   256.858B           54.07            NaN
# 1   98.275M          176.437M   598.616B           52.41            NaN
# 2   87.142M           35.848M     2.644B             NaN            NaN
# 3     72.3M           40.575M    12.125B             NaN            NaN
# 4   62.223M           25.781M    43.762B           15.44            NaN

# %% [markdown]
# The dropna() function was used to remove the '52 Week Range' column, which consists of NaN
# values. Replaced NaN values with 0's using the fillna() function in the 'PE Ratio (TTM)' column.
# The apply(convert_scale) function was used to convert the scale, change the datatypes from
# object to float64 for 'Volume', 'Avg Vol (3 month)', 'Market Cap' columns. Lastly, the % was
# changed to ' ' with a regex=True param. The dataype for '% Change' column was changed using
# pandas to_numeric function.

# %%
# fill in 0 for NaN values 
stocks_df[['PE Ratio (TTM)', 'Avg Vol (3 month)']] = stocks_df[['PE Ratio (TTM)', 'Avg Vol (3 month)']].fillna(0) # fill in 0 where NaN
stocks_df.dropna(axis=1, thresh=9, inplace=True) # drop a column

#using .apply function to convert the scale n datatypes
stocks_df['Volume'] = stocks_df['Volume'].apply(convert_scale) 
stocks_df['Avg Vol (3 month)'] = stocks_df['Avg Vol (3 month)'].apply(convert_scale)
stocks_df['Market Cap'] = stocks_df['Market Cap'].apply(convert_scale)

# replacing %:'' and changing the dtype of column
stocks_df['% Change'] = pd.to_numeric(stocks_df['% Change'].replace({'%' : ''}, regex=True))
stocks_df.sort_values('Symbol', inplace=True) # sorting the rows in alphabetical order.

print(stocks_df.shape)
print(f'Datatypes after the change: \n') 
stocks_df.info() # shows all the columns, non null count and dtypes
stocks_df.head()
# Out:
# (75, 9)
# Datatypes after the change:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 11 to 63
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symbol             75 non-null     object
#  1   Name               75 non-null     object
#  2   Price (Intraday)   75 non-null     float64
#  3   Change             75 non-null     float64
#  4   % Change           75 non-null     float64
#  5   Volume             75 non-null     float64
#  6   Avg Vol (3 month)  75 non-null     float64
#  7   Market Cap         75 non-null     float64
#  8   PE Ratio (TTM)     75 non-null     float64
# dtypes: float64(7), object(2)
# memory usage: 5.9+ KB
#    Symbol                   Name  Price (Intraday)  Change  % Change  \
# 11   AAPL             Apple Inc.            157.65   -0.63     -0.40
# 4    ABEV             Ambev S.A.              2.78    0.12      4.51
# 58   AFRM  Affirm Holdings, Inc.              9.47   -0.75     -7.34
# 24   AFRM  Affirm Holdings, Inc.              9.47   -0.75     -7.34
# 69    AGL    agilon health, inc.             27.22   -1.33     -4.66
#
#         Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 11  45992000.0         69639000.0  2.494000e+12           26.77
# 4   62223000.0         25781000.0  4.376200e+10           15.44
# 58  23167000.0         19465000.0  2.784000e+09            0.00
# 24  23167000.0         19465000.0  2.784000e+09            0.00
# 69   3960000.0          2342000.0  1.124500e+10            0.00

# %% [markdown]
# The pandas concat() function stacks data sets on top of each other. Collecting most_active,
# gainers and losers stocks, most_active stocks could be a gainer or a loser for any given day.
# Thus, the duplicated() function was used to check for any duplicate rows then drop_duplicates deletes the duplicated row/s.

# %%
# find if there are any duplicated rows referencing column Symbol

duplicate = stocks_df[stocks_df.duplicated('Symbol')]
duplicate
# Out:
#    Symbol                              Name  Price (Intraday)  Change  \
# 24   AFRM             Affirm Holdings, Inc.              9.47   -0.75
# 31    AMC  AMC Entertainment Holdings, Inc.              5.15    0.60
# 0    BABA     Alibaba Group Holding Limited             98.40   12.28
# 56   LYFT                        Lyft, Inc.              8.87   -0.73
# 21    RIG                   Transocean Ltd.              6.68    0.48
# 16   SNAP                         Snap Inc.             11.06   -0.68
#
#     % Change       Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 24     -7.34   23167000.0         19465000.0  2.784000e+09            0.00
# 31     13.19   87142000.0         35848000.0  2.644000e+09            0.00
# 0      14.26  118057000.0         22989000.0  2.568580e+11           54.07
# 56     -7.60   50052000.0         20775000.0  3.354000e+09            0.00
# 21      7.74   24853000.0         25300000.0  4.889000e+09            0.00
# 16     -5.79   30013000.0         33257000.0  1.749000e+10            0.00

# %%
# if there is any duplicates drop_duplicates function will delete the rows, 
# keep='last' param keeps the last occurence and drops anything else. 
# inplace= True would replace the original df 
stocks_df.drop_duplicates(subset=['Symbol'], keep='last', inplace=True, ignore_index=True) 
print(stocks_df.shape) # prints updated shape of df

pd.set_option('display.max_rows', None) # displays all the rows
stocks_df # dispalys all the rows in a df
# Out:
# (69, 9)
#     Symbol                                            Name  Price (Intraday)  \
# 0     AAPL                                      Apple Inc.          157.6500
# 1     ABEV                                      Ambev S.A.            2.7800
# 2     AFRM                           Affirm Holdings, Inc.            9.4700
# 3      AGL                             agilon health, inc.           27.2200
# 4     AGTI                                   Agiliti, Inc.           15.4100
# 5      AMC                AMC Entertainment Holdings, Inc.            5.1500
# 6      AMD                    Advanced Micro Devices, Inc.           94.5600
# 7     AMKR                          Amkor Technology, Inc.           24.5100
# 8     AMZN                                Amazon.com, Inc.           97.2400
# 9      APE                AMC Entertainment Holdings, Inc.            1.4700
# 10    AXNX                                   Axonics, Inc.           54.8800
# 11    BABA                   Alibaba Group Holding Limited           98.4000
# 12     BAC                     Bank of America Corporation           28.1200
# 13   BCLYF                                    Barclays PLC            1.7050
# 14    BOWL                                   Bowlero Corp.           16.4000
# 15    CABO                                 Cable One, Inc.          657.3800
# 16     CCL                      Carnival Corporation & plc            9.3300
# 17      CS                          Credit Suisse Group AG            0.8531
# 18     DRS                              Leonardo DRS, Inc.           11.6000
# 19     EDU  New Oriental Education & Technology Group Inc.           39.5600
# 20      EE                         Excelerate Energy, Inc.           21.2700
# 21       F                              Ford Motor Company           11.6000
# 22      FG                      F&G Annuities & Life, Inc.           17.5100
# 23     FRC                             First Republic Bank           13.5000
# 24  FRC-PH                             First Republic Bank            5.8600
# 25  FRC-PI                             First Republic Bank            6.1000
# 26    FUTU                           Futu Holdings Limited           46.2000
# 27      GH                           Guardant Health, Inc.           22.9800
# 28    GOOG                                   Alphabet Inc.          101.3600
# 29   GOOGL                                   Alphabet Inc.          101.0300
# 30     HUM                                     Humana Inc.          483.4100
# 31     IHS                             IHS Holding Limited            8.5400
# 32    INTC                               Intel Corporation           29.2900
# 33    ITCI                  Intra-Cellular Therapies, Inc.           55.7300
# 34    ITUB                      Itaú Unibanco Holding S.A.            4.5600
# 35     KGC                        Kinross Gold Corporation            4.5900
# 36    LAZR                      Luminar Technologies, Inc.            6.3400
# 37    LCID                               Lucid Group, Inc.            7.5500
# 38      LI                                    Li Auto Inc.           24.7500
# 39   LINRF                      Liontown Resources Limited            1.6700
# 40     LPL                            LG Display Co., Ltd.            6.3200
# 41    LUMN                        Lumen Technologies, Inc.            2.6500
# 42   LUNMF                       Lundin Mining Corporation            6.1500
# 43    LYFT                                      Lyft, Inc.            8.8700
# 44     MKC               McCormick & Company, Incorporated           81.1800
# 45     NIO                                        NIO Inc.            9.2000
# 46    NVDA                              NVIDIA Corporation          264.1000
# 47     OLK                         Olink Holding AB (publ)           19.8500
# 48   OROCF                                  Allkem Limited            7.6400
# 49   PHJMF                PT Hanjaya Mandala Sampoerna Tbk            0.0770
# 50   PILBF                        Pilbara Minerals Limited            2.5600
# 51    PROK                                 ProKidney Corp.           12.0300
# 52     PVH                                       PVH Corp.           88.3600
# 53     RIG                                 Transocean Ltd.            6.6800
# 54     RUM                                     Rumble Inc.            8.8600
# 55    SGML                       Sigma Lithium Corporation           36.9500
# 56  SLG-PI                           SL Green Realty Corp.           17.2300
# 57    SMCI                      Super Micro Computer, Inc.          102.7800
# 58    SNAP                                       Snap Inc.           11.0600
# 59     SPR               Spirit AeroSystems Holdings, Inc.           32.8400
# 60     SPT                             Sprout Social, Inc.           57.1500
# 61     SYM                                   Symbotic Inc.           20.9400
# 62     TAL                             TAL Education Group            6.4000
# 63   TCEHY                        Tencent Holdings Limited           49.9000
# 64     TEO                          Telecom Argentina S.A.            5.0400
# 65     TKC               Turkcell Iletisim Hizmetleri A.S.            4.1300
# 66    TSLA                                     Tesla, Inc.          189.1900
# 67   TYCMY           Tingyi (Cayman Islands) Holding Corp.           32.3400
# 68   VONOY                                      Vonovia SE            8.4200
#
#      Change  % Change       Volume  Avg Vol (3 month)    Market Cap  \
# 0   -0.6300     -0.40   45992000.0         69639000.0  2.494000e+12
# 1    0.1200      4.51   62223000.0         25781000.0  4.376200e+10
# 2   -0.7500     -7.34   23167000.0         19465000.0  2.784000e+09
# 3   -1.3300     -4.66    3960000.0          2342000.0  1.124500e+10
# 4   -0.8300     -5.11     215561.0           265251.0  2.062000e+09
# 5    0.6000     13.19   87142000.0         35848000.0  2.644000e+09
# 6   -2.0500     -2.12   59150000.0         62491000.0  1.523730e+11
# 7   -1.1900     -4.63     915917.0          1116000.0  6.012000e+09
# 8   -0.8000     -0.82   38720000.0         68984000.0  9.964470e+11
# 9    0.0600      4.26   49359000.0         28333000.0  4.705000e+09
# 10  -2.6300     -4.57     585316.0           689791.0  2.742000e+09
# 11  12.2800     14.26  118057000.0         22989000.0  2.568580e+11
# 12  -0.3700     -1.30   62125000.0         55468000.0  2.249400e+11
# 13   0.1450      9.29      20417.0            79346.0  2.834500e+10
# 14   1.2000      7.89    2952000.0          1370000.0  2.797000e+09
# 15 -31.5400     -4.58      64251.0            61851.0  3.766000e+09
# 16   0.5400      6.14   72300000.0         40575000.0  1.212500e+10
# 17  -0.0104     -1.20   51276000.0         48003000.0  3.362000e+09
# 18  -1.2500     -9.73    2086000.0           658455.0  3.018000e+09
# 19   2.5000      6.75    2238000.0          2316000.0  6.723000e+09
# 20   1.5600      7.91     431086.0           262298.0  2.303000e+09
# 21   0.0800      0.69   40517000.0         69259000.0  4.624000e+10
# 22  -0.8700     -4.73     145572.0           210053.0  2.213000e+09
# 23  -0.3200     -2.32   55178000.0         28618000.0  2.514000e+09
# 24  -0.7700    -11.61     354664.0           128058.0  3.775000e+09
# 25  -0.8400    -12.10     501408.0           175180.0  3.846000e+09
# 26  -3.1100     -6.31   10640000.0          3519000.0  6.487000e+09
# 27  -1.3500     -5.55    1423000.0          2017000.0  2.359000e+09
# 28  -1.7000     -1.65   24913000.0         32432000.0  1.294000e+12
# 29  -1.4300     -1.40   32022000.0         40176000.0  1.297000e+12
# 30 -23.5800     -4.65    1652000.0          1047000.0  6.046300e+10
# 31   1.4400     20.28     872623.0           163945.0  2.833000e+09
# 32   0.1100      0.38   37408000.0         45505000.0  1.211730e+11
# 33   7.8500     16.40    3622000.0           748316.0  5.310000e+09
# 34   0.0400      0.88   25642000.0         33159000.0  4.457300e+10
# 35   0.1700      3.85   24486000.0         15457000.0  5.622000e+09
# 36  -0.3400     -5.09    6856000.0         13175000.0  2.341000e+09
# 37  -0.5900     -7.25   19941000.0         29524000.0  1.382100e+10
# 38   1.5400      6.64    7656000.0          7549000.0  2.415000e+10
# 39   0.6450     62.93     108330.0             8302.0  3.671000e+09
# 40   0.5700      9.91     341664.0           216870.0  4.531000e+09
# 41   0.1100      4.33   25913000.0         36151000.0  2.653000e+09
# 42   0.4200      7.38      36080.0           118798.0  4.744000e+09
# 43  -0.7300     -7.60   50052000.0         20775000.0  3.354000e+09
# 44   7.1200      9.61    6329000.0          1448000.0  2.177100e+10
# 45   0.2700      3.02   31106000.0         44976000.0  1.578000e+10
# 46  -1.2100     -0.46   35504000.0         50379000.0  6.581370e+11
# 47  -1.7400     -8.06     113615.0           165250.0  2.464000e+09
# 48   0.8000     11.76      24036.0            21130.0  4.872000e+09
# 49   0.0200     35.09     209275.0           316318.0  1.222900e+10
# 50   0.2600     11.30     227385.0           370451.0  7.675000e+09
# 51  -0.9600     -7.39     230547.0           212916.0  2.800000e+09
# 52  14.7400     20.02    4694000.0          1033000.0  5.599000e+09
# 53   0.4800      7.74   24853000.0         25300000.0  4.889000e+09
# 54   0.5300      6.36     711293.0          1044000.0  2.473000e+09
# 55   2.8600      8.39    2212000.0           792098.0  3.824000e+09
# 56   1.3900      8.78     192108.0            32449.0  5.003000e+09
# 57  -8.1200     -7.32    2076000.0          1541000.0  5.513000e+09
# 58  -0.6800     -5.79   30013000.0         33257000.0  1.749000e+10
# 59   1.9800      6.42    1430000.0          2024000.0  3.450000e+09
# 60  -2.7500     -4.59     671908.0           613890.0  3.147000e+09
# 61  -2.0300     -8.84     433807.0           460405.0  1.163300e+10
# 62   0.5000      8.47    9695000.0          8067000.0  4.153000e+09
# 63   3.7100      8.03    6390000.0          3678000.0  4.777830e+11
# 64   0.4000      8.62     193008.0           132963.0  2.596000e+09
# 65  -0.3000     -6.77     420984.0           445921.0  3.606000e+09
# 66  -2.6200     -1.37   98275000.0        176437000.0  5.986160e+11
# 67  -3.8100    -10.54     132378.0             6761.0  9.110000e+09
# 68  -0.5200     -5.82    1521000.0           203413.0  1.363900e+10
#
#     PE Ratio (TTM)
# 0            26.77
# 1            15.44
# 2             0.00
# 3             0.00
# 4            64.21
# 5             0.00
# 6           116.74
# 7             7.88
# 8             0.00
# 9             0.00
# 10            0.00
# 11           54.07
# 12            8.82
# 13            4.74
# 14            0.00
# 15           16.77
# 16            0.00
# 17            0.00
# 18            4.20
# 19            0.00
# 20           11.31
# 21            0.00
# 22            4.21
# 23            1.48
# 24            0.74
# 25            0.77
# 26           21.39
# 27            0.00
# 28           22.93
# 29           22.81
# 30           21.87
# 31            0.00
# 32           15.10
# 33            0.00
# 34            8.00
# 35          229.50
# 36            0.00
# 37            0.00
# 38            0.00
# 39            0.00
# 40            0.00
# 41            0.00
# 42           10.99
# 43            0.00
# 44           32.21
# 45            0.00
# 46          112.38
# 47            0.00
# 48            9.79
# 49            0.00
# 50            6.92
# 51            0.00
# 52           13.81
# 53            0.00
# 54            0.00
# 55            0.00
# 56            2.55
# 57           10.01
# 58            0.00
# 59            0.00
# 60            0.00
# 61            0.00
# 62            0.00
# 63           18.76
# 64            0.00
# 65            6.26
# 66           52.41
# 67           20.86
# 68            0.00

# %% [markdown]
# ## Feature 2.1 Data Analysis:

# %% [markdown]
# Important Note: Each time the code is run, new stocks could be present because the code webscrapes from the website using .read_html. During trading hours, most active, gainers and losers change over time. As a result, some of the queries might not be displaying any results.

# %%
# describe method displays the basic statistical values
stocks_df.describe().plot(subplots=True, figsize=(14,8))
print(stocks_df.describe())
# Out:
#        Price (Intraday)     Change   % Change        Volume  \
# count         69.000000  69.000000  69.000000  6.900000e+01
# mean          49.658335  -0.532035   2.576957  1.899883e+07
# std          103.398218   5.688593  11.461132  2.677578e+07
# min            0.077000 -31.540000 -12.100000  2.041700e+04
# 25%            6.340000  -1.190000  -5.090000  4.310860e+05
# 50%           15.410000  -0.010400  -0.400000  3.622000e+06
# 75%           46.200000   0.540000   7.910000  3.110600e+07
# max          657.380000  14.740000  62.930000  1.180570e+08
#
#        Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# count       6.900000e+01  6.900000e+01       69.000000
# mean        1.767866e+07  1.321585e+11       14.155072
# std         2.836963e+07  3.939339e+11       34.547623
# min         6.761000e+03  2.062000e+09        0.000000
# 25%         2.652510e+05  3.147000e+09        0.000000
# 50%         2.017000e+06  5.310000e+09        0.000000
# 75%         2.952400e+07  2.177100e+10       13.810000
# max         1.764370e+08  2.494000e+12      229.500000

# %% [markdown]
# 1. Find all rows that have 'Ban' in its name column?

# %% [markdown]
# At the time of this data analysis, bank stocks are the most active and volatile. Some banks use
# 'Banc, while others use 'Bank', therefore 'Ban' was used as the search term.

# %%
# find all rows that have 'Ban' in its name column?
stocks_df.loc[stocks_df.Name.str.contains('(?i)Ban', regex=True)]
# Out:
#     Symbol                         Name  Price (Intraday)  Change  % Change  \
# 12     BAC  Bank of America Corporation             28.12   -0.37     -1.30
# 23     FRC          First Republic Bank             13.50   -0.32     -2.32
# 24  FRC-PH          First Republic Bank              5.86   -0.77    -11.61
# 25  FRC-PI          First Republic Bank              6.10   -0.84    -12.10
# 34    ITUB   Itaú Unibanco Holding S.A.              4.56    0.04      0.88
#
#         Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 12  62125000.0         55468000.0  2.249400e+11            8.82
# 23  55178000.0         28618000.0  2.514000e+09            1.48
# 24    354664.0           128058.0  3.775000e+09            0.74
# 25    501408.0           175180.0  3.846000e+09            0.77
# 34  25642000.0         33159000.0  4.457300e+10            8.00

# %% [markdown]
# 2. Get all the rows where volume is at least 20 million and the daily change is at least -5?

# %%
volume_change = stocks_df.query('Volume >= 20000000 and Change <= -5')[['Name', 'Change', 'Volume']]
volume_change
# Out:
# Empty DataFrame
# Columns: [Name, Change, Volume]
# Index: []

# %% [markdown]
# 3. Find stocks that dropped below 25% and print its symbol, name and % Change ?

# %%
stocks_below_25 = stocks_df.query('`% Change` < -25')[['Symbol', 'Name', '% Change']]
stocks_below_25
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, % Change]
# Index: []

# %% [markdown]
# 4. Any stocks that performed over 10% today and how many times they transacted today?

# %%
stocks_above_20 = stocks_df.query('`% Change` > 10')[['Symbol', 'Name', '% Change', 'Volume']]
stocks_above_20
# Out:
#    Symbol                              Name  % Change       Volume
# 5     AMC  AMC Entertainment Holdings, Inc.     13.19   87142000.0
# 11   BABA     Alibaba Group Holding Limited     14.26  118057000.0
# 31    IHS               IHS Holding Limited     20.28     872623.0
# 33   ITCI    Intra-Cellular Therapies, Inc.     16.40    3622000.0
# 39  LINRF        Liontown Resources Limited     62.93     108330.0
# 48  OROCF                    Allkem Limited     11.76      24036.0
# 49  PHJMF  PT Hanjaya Mandala Sampoerna Tbk     35.09     209275.0
# 50  PILBF          Pilbara Minerals Limited     11.30     227385.0
# 52    PVH                         PVH Corp.     20.02    4694000.0

# %% [markdown]
# 5. Find a company that starts with "S", has a PE Ratio greater than or equal to 5 and the difference is less than or equal to 5?

# %%
Symbol_s = stocks_df.loc[(stocks_df['PE Ratio (TTM)']>=5) & (stocks_df['Change']<= 5) & (stocks_df['Symbol'].str.startswith('S')),['Symbol', 'Name', 'Change', 'PE Ratio (TTM)']]
Symbol_s
# Out:
#    Symbol                        Name  Change  PE Ratio (TTM)
# 57   SMCI  Super Micro Computer, Inc.   -8.12           10.01

# %% [markdown]
# 6. Is there any company that has Market Cap of 100 Billion or more? print only name and market cap.

# %% [markdown]
# In order to filter a DataFrame column that has spaces with the query method, we wrap the column using backticks. While this may not look great, it does allow us to use any column in the method.

# %%
large_market_cap = stocks_df.query("`Market Cap` > 100000000000")[['Name', 'Market Cap']]
#print(large_market_cap)

fig = px.bar(large_market_cap, x='Name', y='Market Cap', title='Companies valued at $100 Billion or more',)
fig.show()

# %% [markdown]
# 7. List of companies to invest in that are less than $10 per share?

# %%
com_below_10 = stocks_df[stocks_df['Price (Intraday)'] <= 10]
print(com_below_10.shape)
com_below_10
# Out:
# (29, 9)
#     Symbol                               Name  Price (Intraday)  Change  \
# 1     ABEV                         Ambev S.A.            2.7800  0.1200
# 2     AFRM              Affirm Holdings, Inc.            9.4700 -0.7500
# 5      AMC   AMC Entertainment Holdings, Inc.            5.1500  0.6000
# 9      APE   AMC Entertainment Holdings, Inc.            1.4700  0.0600
# 13   BCLYF                       Barclays PLC            1.7050  0.1450
# 16     CCL         Carnival Corporation & plc            9.3300  0.5400
# 17      CS             Credit Suisse Group AG            0.8531 -0.0104
# 24  FRC-PH                First Republic Bank            5.8600 -0.7700
# 25  FRC-PI                First Republic Bank            6.1000 -0.8400
# 31     IHS                IHS Holding Limited            8.5400  1.4400
# 34    ITUB         Itaú Unibanco Holding S.A.            4.5600  0.0400
# 35     KGC           Kinross Gold Corporation            4.5900  0.1700
# 36    LAZR         Luminar Technologies, Inc.            6.3400 -0.3400
# 37    LCID                  Lucid Group, Inc.            7.5500 -0.5900
# 39   LINRF         Liontown Resources Limited            1.6700  0.6450
# 40     LPL               LG Display Co., Ltd.            6.3200  0.5700
# 41    LUMN           Lumen Technologies, Inc.            2.6500  0.1100
# 42   LUNMF          Lundin Mining Corporation            6.1500  0.4200
# 43    LYFT                         Lyft, Inc.            8.8700 -0.7300
# 45     NIO                           NIO Inc.            9.2000  0.2700
# 48   OROCF                     Allkem Limited            7.6400  0.8000
# 49   PHJMF   PT Hanjaya Mandala Sampoerna Tbk            0.0770  0.0200
# 50   PILBF           Pilbara Minerals Limited            2.5600  0.2600
# 53     RIG                    Transocean Ltd.            6.6800  0.4800
# 54     RUM                        Rumble Inc.            8.8600  0.5300
# 62     TAL                TAL Education Group            6.4000  0.5000
# 64     TEO             Telecom Argentina S.A.            5.0400  0.4000
# 65     TKC  Turkcell Iletisim Hizmetleri A.S.            4.1300 -0.3000
# 68   VONOY                         Vonovia SE            8.4200 -0.5200
#
#     % Change      Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 1       4.51  62223000.0         25781000.0  4.376200e+10           15.44
# 2      -7.34  23167000.0         19465000.0  2.784000e+09            0.00
# 5      13.19  87142000.0         35848000.0  2.644000e+09            0.00
# 9       4.26  49359000.0         28333000.0  4.705000e+09            0.00
# 13      9.29     20417.0            79346.0  2.834500e+10            4.74
# 16      6.14  72300000.0         40575000.0  1.212500e+10            0.00
# 17     -1.20  51276000.0         48003000.0  3.362000e+09            0.00
# 24    -11.61    354664.0           128058.0  3.775000e+09            0.74
# 25    -12.10    501408.0           175180.0  3.846000e+09            0.77
# 31     20.28    872623.0           163945.0  2.833000e+09            0.00
# 34      0.88  25642000.0         33159000.0  4.457300e+10            8.00
# 35      3.85  24486000.0         15457000.0  5.622000e+09          229.50
# 36     -5.09   6856000.0         13175000.0  2.341000e+09            0.00
# 37     -7.25  19941000.0         29524000.0  1.382100e+10            0.00
# 39     62.93    108330.0             8302.0  3.671000e+09            0.00
# 40      9.91    341664.0           216870.0  4.531000e+09            0.00
# 41      4.33  25913000.0         36151000.0  2.653000e+09            0.00
# 42      7.38     36080.0           118798.0  4.744000e+09           10.99
# 43     -7.60  50052000.0         20775000.0  3.354000e+09            0.00
# 45      3.02  31106000.0         44976000.0  1.578000e+10            0.00
# 48     11.76     24036.0            21130.0  4.872000e+09            9.79
# 49     35.09    209275.0           316318.0  1.222900e+10            0.00
# 50     11.30    227385.0           370451.0  7.675000e+09            6.92
# 53      7.74  24853000.0         25300000.0  4.889000e+09            0.00
# 54      6.36    711293.0          1044000.0  2.473000e+09            0.00
# 62      8.47   9695000.0          8067000.0  4.153000e+09            0.00
# 64      8.62    193008.0           132963.0  2.596000e+09            0.00
# 65     -6.77    420984.0           445921.0  3.606000e+09            6.26
# 68     -5.82   1521000.0           203413.0  1.363900e+10            0.00

# %% [markdown]
# ## Feature 3: Visualize/Present your data.

# %% [markdown]
# In order to find the top five companies by 3 month Average Volume for a particular day, and see how those
# stocks are performing for the past year, yfinance library was used. yfinance is a package
# designed to download historical stock data from Yahoo Finance. Data is visualized using the
# plotly library.

# %%
top_5_company = stocks_df.nlargest(5,['Avg Vol (3 month)'])
top_5_company
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 66   TSLA                   Tesla, Inc.            189.19   -2.62     -1.37
# 0    AAPL                    Apple Inc.            157.65   -0.63     -0.40
# 21      F            Ford Motor Company             11.60    0.08      0.69
# 8    AMZN              Amazon.com, Inc.             97.24   -0.80     -0.82
# 6     AMD  Advanced Micro Devices, Inc.             94.56   -2.05     -2.12
#
#         Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 66  98275000.0        176437000.0  5.986160e+11           52.41
# 0   45992000.0         69639000.0  2.494000e+12           26.77
# 21  40517000.0         69259000.0  4.624000e+10            0.00
# 8   38720000.0         68984000.0  9.964470e+11            0.00
# 6   59150000.0         62491000.0  1.523730e+11          116.74

# %%
# taking a column and chaging it to a list
top_5_volume = (top_5_company.Symbol).to_list()
top_5_volume
# Out:
# ['TSLA', 'AAPL', 'F', 'AMZN', 'AMD']

# %% [markdown]
# With the yfinance's download method, multiple ticker symbols can be downloaded at the same
# time. Each time the list is generated it is passed as the file to run. Since this project is not rigid
# and the data changes according to stock market performance. Data is downloaded for a one
# year period, with a period of one day intervals, as the stock market is open, timezones are
# ignored. To remove the 'Adjust Close Price' column, use auto_adjust=True. Dividends and splits
# of stock can be downloaded by setting actions ='inline'. Which this project does not include.

# %%
# downloads the stock data for the list of tickers for 1y period
ticker = yf.download(top_5_volume, period='1y',interval='1d', ignore_tz=True, progress=False, auto_adjust=True )
ticker.info() # displays information about the columns
pd.set_option('display.max_columns', None) # displays all the columns with a scroll bar
ticker.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2022-03-29 to 2023-03-28
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   251 non-null    float64
#  1   (Close, AMD)    251 non-null    float64
#  2   (Close, AMZN)   251 non-null    float64
#  3   (Close, F)      251 non-null    float64
#  4   (Close, TSLA)   251 non-null    float64
#  5   (High, AAPL)    251 non-null    float64
#  6   (High, AMD)     251 non-null    float64
#  7   (High, AMZN)    251 non-null    float64
#  8   (High, F)       251 non-null    float64
#  9   (High, TSLA)    251 non-null    float64
#  10  (Low, AAPL)     251 non-null    float64
#  11  (Low, AMD)      251 non-null    float64
#  12  (Low, AMZN)     251 non-null    float64
#  13  (Low, F)        251 non-null    float64
#  14  (Low, TSLA)     251 non-null    float64
#  15  (Open, AAPL)    251 non-null    float64
#  16  (Open, AMD)     251 non-null    float64
#  17  (Open, AMZN)    251 non-null    float64
#  18  (Open, F)       251 non-null    float64
#  19  (Open, TSLA)    251 non-null    float64
#  20  (Volume, AAPL)  251 non-null    int64
#  21  (Volume, AMD)   251 non-null    int64
#  22  (Volume, AMZN)  251 non-null    int64
#  23  (Volume, F)     251 non-null    int64
#  24  (Volume, TSLA)  251 non-null    int64
# dtypes: float64(20), int64(5)
# memory usage: 51.0 KB
#                  Close                                                 \
#                   AAPL         AMD        AMZN          F        TSLA
# Date
# 2022-03-29  177.882462  123.230003  169.315002  16.253317  366.523346
# 2022-03-30  176.699615  119.220001  166.300995  15.813794  364.663330
# 2022-03-31  173.558655  109.339996  162.997498  15.484147  359.200012
# 2022-04-01  173.260452  108.190002  163.559998  15.246070  361.529999
# 2022-04-04  177.365585  110.529999  168.346497  15.255226  381.816681
#
#                   High                                                 \
#                   AAPL         AMD        AMZN          F        TSLA
# Date
# 2022-03-29  177.932148  123.709999  170.831497  16.299100  371.589996
# 2022-03-30  178.528533  125.669998  168.950500  16.170909  371.316681
# 2022-03-31  176.958061  116.379997  166.494995  15.887047  367.713318
# 2022-04-01  173.827027  111.419998  165.826996  15.703910  364.916656
# 2022-04-04  177.415287  110.940002  168.394501  15.319323  383.303345
#
#                    Low                                                 \
#                   AAPL         AMD        AMZN          F        TSLA
# Date
# 2022-03-29  175.278227  119.589996  167.868500  15.575714  357.703339
# 2022-03-30  175.636051  118.589996  165.500000  15.749697  361.333344
# 2022-03-31  173.349913  109.019997  162.953506  15.108718  358.880005
# 2022-04-01  170.904727  106.099998  162.319504  14.962210  355.546661
# 2022-04-04  173.389670  107.029999  163.205505  14.980523  357.510010
#
#                   Open                                                 \
#                   AAPL         AMD        AMZN          F        TSLA
# Date
# 2022-03-29  175.626125  122.279999  170.384003  15.575714  369.329987
# 2022-03-30  177.474918  123.040001  168.509506  16.042714  363.723328
# 2022-03-31  176.769202  116.309998  166.445007  15.749695  364.856659
# 2022-04-01  172.982139  110.480003  164.149506  15.575715  360.383331
# 2022-04-04  173.518892  109.970001  164.125000  15.255226  363.126678
#
#                Volume
#                  AAPL        AMD      AMZN         F      TSLA
# Date
# 2022-03-29  100589400   94143000  66154000  90676900  73614900
# 2022-03-30   92633200   99476900  56168000  57853400  59865000
# 2022-03-31  103049300  147004800  59966000  52529400  48992700
# 2022-04-01   78751300  111867100  57090000  64695700  54263100
# 2022-04-04   76468400   90123900  49882000  51146500  82035900

# %% [markdown]
# ## Plotting Data

# %% [markdown]
# ##### Plotly is an open-source, interactive data visualization library for Python that is built Plotly JavaScript Library (plotly.js) as sometimes referred to as "plotly.py". Plotly supports over 40 unique chart types covering a wide range of statistical, financial, geographic, scientific, and 3-D use-cases to create interactive web-based visualizations that can be displayed in Jupyter notebook, saved to standalone HTML files, or served as part of pure Python-built web applications using Dash.

# %% [markdown]
# In order to get the data for closing price, Only the Close column was selected for all five tickers. The highest and lowest Closing price is shown using .max and .min method. Then, the 1 year data is plotted on a line graph. Since it is interactive data, as the user hovers over the graph, it shows the ticker symbol, trading date and the price on that day.

# %%
close = ticker.Close
#print(close)
max = close.max()
print(f'The highest closing price for these companies are: \n{max}\n')
min = close.min()
print(f'The lowest closing price for these companies are: \n{min}')

fig = px.line(close, title=f"Closing Price for stocks with largest 3mth volume on {today} for the past year",) 
fig.show()
# Out:
# The highest closing price for these companies are:
# AAPL    177.882462
# AMD     123.230003
# AMZN    169.315002
# F        16.253317
# TSLA    381.816681
# dtype: float64
#
# The lowest closing price for these companies are:
# AAPL    124.829399
# AMD      55.939999
# AMZN     81.820000
# F        10.194802
# TSLA    108.099998
# dtype: float64

# %% [markdown]
# In order to get the data for opening price, only the Open column was selected for all five tickers. The highest and lowest Opening price is shown using .max and .min method. Then, the 1 year data is plotted on a filled area graph. It is an interactive data, as the user hovers over the graph, it shows the ticker symbol, trading date and the price on that day.

# %%
open = ticker.Open
max = open.max()
print(f'The highest opening price for these companies are: \n{max}\n')
min = open.min()
print(f'The lowest opening price for these companies are: \n{min}')
px.area(open, title=f"Opening price for stocks with largest 3 mth volume on {today} for the past year")
# Out:
# The highest opening price for these companies are:
# AAPL    177.474918
# AMD     123.040001
# AMZN    170.384003
# F        16.042714
# TSLA    378.766663
# dtype: float64
#
# The lowest opening price for these companies are:
# AAPL    125.817904
# AMD      55.520000
# AMZN     82.800003
# F        10.185583
# TSLA    103.000000
# dtype: float64

# %% [markdown]
# In order to get the data for high price, Only the High column was selected for all five tickers. The highest and lowest High price is shown using .max and .min method. Then, the 1 year data is plotted on a plotly bar graph. Since it is an interactive data, as the user hovers over the graph, it shows the ticker symbol, trading date and the price on that day.

# %%
high = ticker.High
max = high.max()
print(f'The highest high price for these companies are: \n{max}\n')
min = high.min()
print(f'The lowest high price for these companies are: \n{min}') 

figure = px.bar(high, title=f" High's for stocks with largest 3mth volume on {today} for the past year")
figure.show()
# Out:
# The highest high price for these companies are:
# AAPL    178.528533
# AMD     125.669998
# AMZN    170.831497
# F        16.299100
# TSLA    384.290009
# dtype: float64
#
# The lowest high price for these companies are:
# AAPL    127.575207
# AMD      58.320000
# AMZN     83.480003
# F        10.333067
# TSLA    111.750000
# dtype: float64

# %% [markdown]
# In order to get the data for low price, Only the Low column was selected for all five tickers. The highest and lowest Low price is shown using .max and .min method. Then, the 1 year data is plotted on a scatter plot. Since it is interactive data, as the user hovers over the graph, it shows the ticker symbol, trading date and the price on that day.

# %%
low = ticker.Low
max = low.max()
print(f'The highest low price for these companies are: \n{max}\n')
min = low.min()
print(f'The lowest low price for these companies are: \n{min}')
figure = px.scatter(ticker.Low, title=f"Low's for stocks with largest 3mth volume on {today} for the past year")
figure.show()
# Out:
# The highest low price for these companies are:
# AAPL    175.636051
# AMD     119.589996
# AMZN    167.868500
# F        15.749697
# TSLA    362.433319
# dtype: float64
#
# The lowest low price for these companies are:
# AAPL    123.980696
# AMD      54.570000
# AMZN     81.430000
# F         9.780003
# TSLA    101.809998
# dtype: float64

# %% [markdown]
# In order to get the data for volume, Only the Volume column was selected for all five tickers. .describe() method is shown to show basic statistics. Then, the 1 year data is plotted on a box plot. As the user hovers over the graph for each company, the graph will display seven different statistics, such as the maximum, median, and minimum trading volume, for a period of one year.

# %%
volume = ticker.Volume
print(volume.describe())

fig = px.box(volume, title=f"Trading Volume of stocks for the past year") 
fig.show()
# Out:
#                AAPL           AMD          AMZN             F          TSLA
# count  2.510000e+02  2.510000e+02  2.510000e+02  2.510000e+02  2.510000e+02
# mean   8.185788e+07  8.209497e+07  7.375479e+07  6.404000e+07  1.091455e+08
# std    2.372884e+07  2.846383e+07  3.049805e+07  2.479019e+07  4.970114e+07
# min    3.519590e+07  2.601890e+07  3.508860e+07  1.298090e+07  4.186470e+07
# 25%    6.687940e+07  6.213795e+07  5.484990e+07  5.015750e+07  7.271860e+07
# 50%    7.657550e+07  7.935500e+07  6.615400e+07  5.878260e+07  9.251910e+07
# 75%    8.988840e+07  9.544705e+07  8.392465e+07  7.390805e+07  1.404976e+08
# max    1.826020e+08  2.253941e+08  2.726620e+08  2.497841e+08  3.065906e+08

# %%
High_Low = ticker.loc[:, ['High', 'Low' ]]
High_Low.head()
High_Low.max()
High_Low.plot(subplots=True, figsize=(10,10))
#ax = High_Low.unstack(level=0).plot(figsize=(14,6))
# Out:
# array([<AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>],
#       dtype=object)
